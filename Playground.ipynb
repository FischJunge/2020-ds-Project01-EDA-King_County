# %% [markdown]
# # Playground

# %%
import pandas as pd
import numpy as np

# %%
df_p = pd.read_csv('data/King_County_House_prices_dataset.csv')

# %%
df_p.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df_p.drop(columns=['sqft_living15', 'sqft_lot15'])
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
df_p.sqft_basement.replace('?','0.0', inplace=True)
df_p.fillna(value=0.0, inplace=True)

# %%
df_p.sqft_basement = df_p.sqft_basement.astype(float).astype(int)
df_p.price = df_p.price.astype(int)

# %%
df_p.dtypes
# Out:
# id                 int64
# date              object
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df_p['price_p_sqft'] = (df_p['price'] / (df_p['sqft_above'] + df_p['sqft_basement'])).astype(int)

# %%
df_p.head()
# Out:
#            id        date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  10/13/2014  221900         3       1.00         1180      5650
# 1  6414100192   12/9/2014  538000         3       2.25         2570      7242
# 2  5631500400   2/25/2015  180000         2       1.00          770     10000
# 3  2487200875   12/9/2014  604000         4       3.00         1960      5000
# 4  1954400510   2/18/2015  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  sqft_above  sqft_basement  yr_built  \
# 0     1.0         0.0   0.0  ...        1180              0      1955
# 1     2.0         0.0   0.0  ...        2170            400      1951
# 2     1.0         0.0   0.0  ...         770              0      1933
# 3     1.0         0.0   0.0  ...        1050            910      1965
# 4     1.0         0.0   0.0  ...        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df_p.dtypes
# Out:
# id                 int64
# date              object
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# price_p_sqft       int64
# dtype: object

# %%
#dummy = pd.get_dummies(df_p['yr_renovated'])

# %%
print(df_p['yr_renovated'])
df_p['renovated'] = ~(df_p.yr_renovated.isin([0]))
df_p['renovated'] = df_p['renovated'].replace('True',1,inplace=True)
#df_p['renovated'] = df_p['renovated'].astype(int)
print(df_p['renovated'])
# Out:
# 0           0.0
# 1        1991.0
# 2           0.0
# 3           0.0
# 4           0.0
#           ...
# 21592       0.0
# 21593       0.0
# 21594       0.0
# 21595       0.0
# 21596       0.0
# Name: yr_renovated, Length: 21597, dtype: float64
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 21592    None
# 21593    None
# 21594    None
# 21595    None
# 21596    None
# Name: renovated, Length: 21597, dtype: object

# %%
df_p.head(5)
# Out:
#            id        date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  10/13/2014  221900         3       1.00         1180      5650
# 1  6414100192   12/9/2014  538000         3       2.25         2570      7242
# 2  5631500400   2/25/2015  180000         2       1.00          770     10000
# 3  2487200875   12/9/2014  604000         4       3.00         1960      5000
# 4  1954400510   2/18/2015  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  sqft_basement  yr_built  yr_renovated  \
# 0     1.0         0.0   0.0  ...              0      1955           0.0
# 1     2.0         0.0   0.0  ...            400      1951        1991.0
# 2     1.0         0.0   0.0  ...              0      1933           0.0
# 3     1.0         0.0   0.0  ...            910      1965           0.0
# 4     1.0         0.0   0.0  ...              0      1987           0.0
#
# ...
